# %%
from models import *

# %%
client = TripAdvisorMongoClient(
    connection_string="mongodb://localhost:27017",
    database="local",
    collection="reviews",
)

business = client.get_businesses()
reviews = client.get_reviews()

# %%
business
# Out:
# [{'business_name': 'Church of Saint Dimitrios - Patron of Thessaloniki',
#   'business_url': 'https://www.tripadvisor.com/Attraction_Review-g189473-d243212-Reviews-Church_of_Saint_Dimitrios_Patron_of_Thessaloniki-Thessaloniki_Thessaloniki_Region_.html'},
#  {'business_name': 'Archaeological Museum of Thessaloniki',
#   'business_url': 'https://www.tripadvisor.com/Attraction_Review-g189473-d243223-Reviews-Archaeological_Museum_of_Thessaloniki-Thessaloniki_Thessaloniki_Region_Central_Mac.html'},
#  {'business_name': 'White Tower of Thessaloniki',
#   'business_url': 'https://www.tripadvisor.com/Attraction_Review-g189473-d243235-Reviews-White_Tower_of_Thessaloniki-Thessaloniki_Thessaloniki_Region_Central_Macedonia.html'},
#  {'business_name': 'Ladadika District',
#   'business_url': 'https://www.tripadvisor.com/Attraction_Review-g189473-d5890333-Reviews-Ladadika_District-Thessaloniki_Thessaloniki_Region_Central_Macedonia.html'},
#  {'business_name': 'Museum of Byzantine Culture',
# ...

# %%
reviews
# Out:
# [{'reviewer': 'Bosko A',
#   'business_reviewed': 'Church of Saint Dimitrios - Patron of Thessaloniki',
#   'review_date': datetime.datetime(2023, 2, 1, 0, 0),
#   'review_title': 'Very Good!',
#   'review_text': 'Beautiful church with amazing art on the wall. When you go into the church it is enormous huge inside and beatiful at the same time. There is a basement beyond a chirch which is historically important, and there is a place where St Demetries was killed. Absolutely recommending everyone to visit this if you are staying at Thessalonikki.',
#   'review_rating': 5,
#   'visit_data': datetime.datetime(2023, 3, 10, 0, 0)},
#  {'reviewer': 'Paul DuBois',
#   'business_reviewed': 'Church of Saint Dimitrios - Patron of Thessaloniki',
#   'review_date': datetime.datetime(2022, 10, 1, 0, 0),
#   'review_title': 'Interesting Church',
# ...
